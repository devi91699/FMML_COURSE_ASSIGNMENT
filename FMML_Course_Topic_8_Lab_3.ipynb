# %% [markdown]
# <a href="https://colab.research.google.com/github/devi91699/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-13 07:56:32--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   193MB/s    in 0.4s
#
# 2024-04-13 07:56:35 (193 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7789   1803.04015v1  In this paper we propose the multi-objective c...  stat
# 23088  cs/0004012v1  This work deals with content-based video index...    cs
# 32064   1109.1844v2  One of the most prominent challenges in cluste...    cs
# 18058  cs/0210004v1  This paper deals with the revision of partiall...    cs
# 16743  1705.07371v1  In this paper, we reformulated the spell corre...    cs
# ...             ...                                                ...   ...
# 21117  1708.02838v1  Reinforcement learning is a proven technique f...    cs
# 21975   1211.3038v4  We prove that the density function of the grad...  stat
# 39263  1506.04566v1  Some recent methods for lossy signal and image...    cs
# 18782   1203.3482v1  Computing the probability of a formula given t...    cs
# 3624   1803.01216v1  In many applications the process of generating...    cs
#
#                                                    title  year  \
# 7789   Multi-objective Contextual Bandit Problem with...  2018
# 23088  Assisted Video Sequences Indexing : Motion Ana...  2000
# 32064                                Weighted Clustering  2011
# 18058                 Revising Partially Ordered Beliefs  2002
# 16743          Spelling Correction as a Foreign Language  2017
# ...                                                  ...   ...
# 21117  Decoupled Learning of Environment Characterist...  2017
# 21975  Gradient density estimation in arbitrary finit...  2012
# 39263  Optimising Spatial and Tonal Data for PDE-base...  2015
# 18782              Formula-Based Probabilistic Inference  2012
# 3624       Deep Bayesian Active Semi-Supervised Learning  2018
#
#                                                 keywords
# 7789   [objective, contextual, similarity, informatio...
# 23088  [viewpoint, automatic, compressed, application...
# 32064  [prominent, challenges, clustering, selecting,...
# 18058  [partially, representation, epistemic, interpr...
# 16743  [reformulated, correction, translation, framew...
# ...                                                  ...
# 21117  [reinforcement, technique, reinforcement, dist...
# 21975  [sufficiently, rightarrow, transformation, uni...
# 39263  [compression, structures, inpainting, differen...
# 18782  [computing, probability, probabilities, associ...
# 3624   [applications, generating, information, expens...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7789     [objective, contextual, similarity, informatio...
# 23088    [viewpoint, automatic, compressed, application...
# 32064    [prominent, challenges, clustering, selecting,...
# 18058    [partially, representation, epistemic, interpr...
# 16743    [reformulated, correction, translation, framew...
#                                ...
# 7189     [classification, distinguish, classification, ...
# 22910    [compressed, formulated, approximately, chervo...
# 22475    [algorithms, introduced, effectively, challeng...
# 19981    [semantics, monotonic, probabilistic, deductiv...
# 12460    [literature, supervised, incorporating, unsupe...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8836 words.
# Out of those 4554 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b68378b0-3f8f-420b-b18d-8ce0ed3018bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b68378b0-3f8f-420b-b18d-8ce0ed3018bf")) {                    Plotly.newPlot(                        "b68378b0-3f8f-420b-b18d-8ce0ed3018bf",                        [{"x":["classical","objective","partitioning","different","providing","locations","algorithm","dependent","jeopardize","introducing","according","similarity","objectives","adaptively","information","dimension","essentially","distances","performance","contextual","conflicting","applications","compressed","summarising","assisting","viewpoint","stability","detectors","sequences","automatic","detection","challenges","differences","advantages","surprisingly","sensitive","paradigms","demonstrates","generalized","delineate","selecting","addressing","properties","frequencies","clustering","associated","appropriate","preferred","prominent","identification","approaches","algorithms","preferable","observations","representation","operations","partially","equivalence","representations","interpretations","possibilistic","epistemic","represented","syntactic","formulated","reformulation","framework","translation","engineering","correction","demonstrate","reformulated","competitive","recurrent","effectiveness","traditionally","automatically","accordingly","linguistic","instances","supervised","experimental","occurring","coordinate","extracting","integrates","extracted","generates","calculate","structural","characterizations","technically","characterization","constructions","reasoning","particular","conceptually","depending","acknowledged","programming","programmer","successful","consequently","understood","relationships","nonmonotonic","commonsense","semantics","robustness","connecting","reconstructing","reconstruction","challenging","recognizing","computing","specificity","geodesics","introduce","significantly","structure","collection","factorization","synthesize","viewpoints","techniques","incorporate","shortcomings","criterion","registration","knowledge","subtraction","restrictive","theoretical","interpretation","successfully","communication","monitoring","methodologies","interactively","corrected","variations","microscopy","consensus","computational","individual","segmented","modalities","automated","intensity","understanding","segmentation","quantitative","comprehensive","collaborative","application","outperforms","experiments","underlying","understand","conducted","perceptual","introduces","mechanism","attention","described","capturing","improvement","introduced","continuous","containing","formulate","discussed","artificial","partition","topological","optimisation","procedures","efficiency","convergence","behavioural","evolutionary","implementation","unsupervised","classification","fundamental","constitutes","presented","manipulate","adaptivity","independently","extraversion","variation","personality","storytelling","expression","filtering","sufficient","neighbouring","movielens","drastically"],"y":[97,159,16,738,85,33,816,71,1,38,111,138,27,24,705,57,25,32,880,66,8,410,24,2,7,14,33,37,92,192,349,115,44,79,34,56,14,60,74,5,40,23,217,11,147,105,83,9,13,121,431,585,8,78,375,63,46,21,236,11,6,8,96,51,50,1,506,119,58,26,557,4,119,134,190,25,194,25,81,84,194,382,15,32,52,24,120,52,18,93,9,5,31,10,119,279,4,37,3,122,2,67,39,22,80,6,6,92,101,13,12,87,264,29,129,12,2,345,258,333,68,50,14,10,388,55,13,45,25,343,6,4,164,44,85,60,33,22,5,10,78,11,10,272,122,24,41,102,27,166,202,75,59,36,250,255,600,102,84,89,23,77,123,171,57,34,148,140,103,65,46,75,141,33,17,32,34,145,108,4,74,119,139,528,100,7,194,8,6,55,2,64,7,2,40,58,65,6,4,16],"type":"bar"},{"x":["classical","objective","partitioning","differ ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4554,), (4554, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8041666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Question</span> <span style='background-color:rgba(0, 255, 0, 0.6393442622950818);'>Answering</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>Unstructured</span> <span style=''>Text</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.5267175572519083);'>Retrieval</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.9047619047619048);'>Comprehension</span> <br/><br/><span style=''>Open</span> <span style=''>domain</span> <span style=''>Question</span> <span style='background-color:rgba(0, 255, 0, 0.6393442622950818);'>Answering</span> <span style=''>(QA)</span> <span style=''>systems</span> <span style=''>must</span> <span style=''>interact</span> <span style=''>with</span> <span style=''>external</span> <span style='background-color:rgba(0, 255, 0, 0.35841584158415835);'>knowledge</span> <span style=''>sources</span> <span style=''>such</span> <span style=''>as</span> <span style=''>web</span> <span style=''>pages</span> <span style=''>to</span> <span style=''>find</span> <span style=''>relevant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Information</span> <span style=''>sources</span> <span style=''>like</span> <span style='background-color:rgba(0, 255, 0, 0.8);'>Wikipedia</span> <span style=''>however</span> <span style=''>are</span> <span style=''>not</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>utilize</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.35841584158415835);'>Knowledge</span> <span style=''>Bases</span> <span style=''>(KBs)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>two</span> <span style=''>step</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>question</span> <span style='background-color:rgba(0, 255, 0, 0.6393442622950818);'>answering</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>unstructured</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consisting</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5267175572519083);'>retrieval</span> <span style=''>step</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.9047619047619048);'>comprehension</span> <span style=''>step</span> <span style=''>For</span> <span style='background-color:rgba(0, 255, 0, 0.9047619047619048);'>comprehension</span> <span style=''>we</span> <span style=''>present</span> <span style=''>an</span> <span style=''>RNN</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3255813953488371);'>attention</span> <span style=''>model</span> <span style=''>with</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>mixture</span> <span style='background-color:rgba(0, 255, 0, 0.43859649122807015);'>mechanism</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>answers</span> <span style=''>from</span> <span style=''>either</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>retrieved</span> <span style=''>articles</span> <span style=''>or</span> <span style=''>a</span> <span style=''>fixed</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>vocabulary</span> <span style=''>For</span> <span style='background-color:rgba(0, 255, 0, 0.52671 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Partially</span> <span style=''>Observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dynamical</span> <span style=''>Systems</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>the</span> <span style=''>model</span> <span style=''>space</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>the</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>using</span> <span style=''>model</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>data</span> <span style=''>items</span> <span style=''>we</span> <span style=''>employ</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style=''>models</span> <span style=''>thus</span> <span style=''>taking</span> <span style=''>into</span> <span style=''>account</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principled</span> <span style=''>manner</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>due</span> <span style=''>to</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>(observational</span> <span style=''>andor</span> <span style=''>dynamic</span> <span style=''>noise)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>(sampling</span> <span style=''>in</span> <span style=''>time)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>We</span> <span style=''>evaluate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>on</span> <span style=''>two</span> <span style=''>testbeds</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biological</span> <span style=''>pathway</span> <span style=''>model</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>double</span> <span style=''>well</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Crucially</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>is</span> <span style=''>not</span> <span style=''>impaired</span> <span style=''>when</span> <span style=''>the</span> <span style=''>model</span> <span style=''>class</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Decreasing</span> <span style=''>Weighted</span> <span style=''>Sorted</span> <span style=''>ell</span> <span style=''>1</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Regularization</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>new</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizers</span> <span style=''>termed</span> <span style=''>it</span> <span style=''>weighted</span> <span style=''>sorted</span> <span style=''>ell</span> <span style=''>1</span> <span style=''>norms</span> <span style=''>(WSL1)</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalizes</span> <span style=''>the</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>it</span> <span style=''>octagonal</span> <span style='background-color:rgba(255, 0, 0, 0.4193548387096775);'>shrinkage</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5163934426229508);'>regression</span> <span style=''>(OSCAR)</span> <span style=''>and</span> <span style=''>also</span> <span style=''>contains</span> <span style=''>the</span> <span style=''>ell</span> <span style=''>1</span> <span style=''>and</span> <span style=''>ell</span> <span style=''>infty</span> <span style=''>norms</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style='background-color:rgba(0, 255, 0, 0.35483870967741943);'>instances</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>the</span> <span style=''>WSL1</span> <span style=''>the</span> <span style=''>sl</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decreasing</span> <span style=''>WSL1</span> <span style=''>(DWSL1)</span> <span style=''>where</span> <span style=''>the</span> <span style=''>elements</span> <span style=''>of</span> <span style=''>the</span> <span style=''>argument</span> <span style=''>vector</span> <span style=''>are</span> <span style=''>sorted</span> <span style=''>in</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style=''>order</span> <span style=''>and</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>are</span> <span style=''>also</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>after</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>the</span> <span style=''>DWSL1</span> <span style=''>is</span> <span style=''>indeed</span> <span style=''>a</span> <span style=''>norm</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>two</span> <span style=''>key</span> <span style=''>tools</span> <span style=''>for</span> <span style=''>its</span> <span style=''>use</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>the</span> <span style=''>dual</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Moreau</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proximity</span> <span style=''>operator</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Developments</span> <span style=''>in</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomized</span> <span style=''>shortest</span> <span style=''>paths</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>of</span> <span style=''>graph</span> <span style=''>node</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <br/><br/><span style=''>There</span> <span style=''>have</span> <span style=''>lately</span> <span style=''>been</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>suggestions</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>on</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalize</span> <span style=''>the</span> <span style=''>shortest</span> <span style=''>path</span> <span style=''>distance</span> <span style=''>and</span> <span style=''>the</span> <span style=''>commute</span> <span style=''>time</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resistance</span> <span style=''>distance</span> <span style=''>The</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developing</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>has</span> <span style=''>risen</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>that</span> <span style=''>the</span> <span style=''>above</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mentioned</span> <span style=''>common</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situations</span> <span style=''>fail</span> <span style=''>to</span> <span style=''>take</span> <span style=''>into</span> <span style=''>account</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>one</span> <span style=''>family</span> <span style=''>of</span> <span style=''>graph</span> <span style=''>node</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>known</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomized</span> <span style=''>shortest</span> <span style=''>path</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>which</span> <span style=''>has</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>foundation</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>physics</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomized</span> <span style=''>shortest</span> <span style=''>path</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12271914132379248)
# 	challenging (0.09445438282647585)
# 	experimental (0.1366726296958855)
# 	segmentation (0.07227191413237925)
# 	representation (0.13416815742397137)
# 	information (0.2522361359570662)
# 	detection (0.12486583184257603)
# 	different (0.2640429338103757)
# 	recognition (0.1334525939177102)
# 	convolutional (0.14561717352415027)
#
# Some Statistics words are:
# 	algorithm (0.3745635910224439)
# 	stochastic (0.12967581047381546)
# 	theoretical (0.1541147132169576)
# 	estimation (0.171072319201995)
# 	variables (0.14962593516209477)
# 	distribution (0.18503740648379052)
# 	statistical (0.16608478802992518)
# 	inference (0.19301745635910225)
# 	dimensional (0.19052369077306733)
# 	regression (0.18453865336658354)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ddcf74e3-040d-4903-9576-1c89c2c1b590" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddcf74e3-040d-4903-9576-1c89c2c1b590")) {                    Plotly.newPlot(                        "ddcf74e3-040d-4903-9576-1c89c2c1b590",                        [{"x":["classical","objective","partitioning","different","providing","locations","algorithm","dependent","jeopardize","introducing","according","similarity","objectives","adaptively","information","dimension","essentially","distances","performance","contextual","conflicting","applications","compressed","summarising","assisting","viewpoint","stability","detectors","sequences","automatic","detection","challenges","differences","advantages","surprisingly","sensitive","paradigms","demonstrates","generalized","delineate","selecting","addressing","properties","frequencies","clustering","associated","appropriate","preferred","prominent","identification","approaches","algorithms","preferable","observations","representation","operations","partially","equivalence","representations","interpretations","possibilistic","epistemic","represented","syntactic","formulated","reformulation","framework","translation","engineering","correction","demonstrate","reformulated","competitive","recurrent","effectiveness","traditionally","automatically","accordingly","linguistic","instances","supervised","experimental","occurring","coordinate","extracting","integrates","extracted","generates","calculate","structural","characterizations","technically","characterization","constructions","reasoning","particular","conceptually","depending","acknowledged","programming","programmer","successful","consequently","understood","relationships","nonmonotonic","commonsense","semantics","robustness","connecting","reconstructing","reconstruction","challenging","recognizing","computing","specificity","geodesics","introduce","significantly","structure","collection","factorization","synthesize","viewpoints","techniques","incorporate","shortcomings","criterion","registration","knowledge","subtraction","restrictive","theoretical","interpretation","successfully","communication","monitoring","methodologies","interactively","corrected","variations","microscopy","consensus","computational","individual","segmented","modalities","automated","intensity","understanding","segmentation","quantitative","comprehensive","collaborative","application","outperforms","experiments","underlying","understand","conducted","perceptual","introduces","mechanism","attention","described","capturing","improvement","introduced","continuous","containing","formulate","discussed","artificial","partition","topological","optimisation","procedures","efficiency","convergence","behavioural","evolutionary","implementation","unsupervised","classification","fundamental","constitutes","presented","manipulate","adaptivity","independently","extraversion","variation","personality","storytelling","expression","filtering","sufficient","neighbouring","movielens","drastically","likelihood","formulation","connected","precomputed","neighbourhood","resulting","approximation","approximate","procedure","graphical","prediction","undirected","generalization","magnitude","statistics","iterative","comparison","embedding","parameters","procrustes","reduction","suggested","constraints","accounting","expectation","determining","distributions","modelling","strategies","description","estimated","estimation","constrained","convolutional","impractical","possibilities","consuming","difficult","synthetically","advancing","estimating","synthetic","realistic","generated","proposing","adversarial","verifying","challenge","counterexample","satisfiability","important","contribution","develop ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	procrustes
# 	newsvendor
# 	asymptotics
# 	nomination
# 	engagement
# 	purchases
# 	monetization
# 	endmember
# 	stringent
# 	ergodicity
# 	prescribe
# 	recidivism
# 	unpenalized
# 	descendant
# 	uncharted
# 	samplings
# 	correntropy
# 	negativity
# 	abundances
# 	blockmodels
# Some words which never appear in Statistics papers:
# 	summarising
# 	assisting
# 	delineate
# 	possibilistic
# 	reformulated
# 	acknowledged
# 	programmer
# 	nonmonotonic
# 	commonsense
# 	extraversion
# 	personality
# 	storytelling
# 	neighbouring
# 	precomputed
# 	mathbbrdtimes
# 	crossover
# 	unidirectional
# 	audiovisual
# 	relatedness
# 	semantical

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.076544425301501e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
